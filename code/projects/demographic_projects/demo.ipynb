# %%
import pandas as pd

# %%
# read data
df = pd.read_csv('./adult_data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
'''
# How many of each race are represented in this dataset? 
# This should be a Pandas series with race names as the index labels.
'''


race_count = (
    df['race'].reset_index() # turn subset into data Frame
    .groupby(by='race').count() # count each race
    .squeeze() # turn into series
)
print(isinstance(race_count,pd.Series))

race_count

# race = df['race'].reset_index()
# race_df = (
#     race.groupby(by='race').count()
#     .rename(columns={'index':'count'})
#     )
# print(isinstance(race_df,pd.DataFrame))
# print(race_df.index)

# # turn subset to series
# race_count = race_df.squeeze()
# Out:
# True
# race
# Amer-Indian-Eskimo      311
# Asian-Pac-Islander     1039
# Black                  3124
# Other                   271
# White                 27816
# Name: index, dtype: int64

# %%
men_age_df = df[df['sex'] == 'Male'][['age','sex']]
round(men_age_df['age'].mean(),1)
# Out:
# 39.4

# %%
# percentage of bachelors
Total_pax = df['sex'].count()
Total_pax
# Out:
# 32561

# %%
bac_num = (df[df['education'] == 'Bachelors']['sex'].count())

# %%
bac_percent = (bac_num/Total_pax)*100
round(bac_percent,1)
# Out:
# 16.4

# %%
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
higher_education_df= (df[
    df['education']
    .isin(['Bachelors','Masters','Doctorate'])
    ])

higher_education_df
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
w_highedu_over50k = higher_education_df[higher_education_df['salary']== '>50K'].sex.count()
higher_education_rich = w_highedu_over50k * 100 / higher_education_df.sex.count()

# %%
higher_education_rich
# Out:
# 46.535843011613935

# %%
lower_education_df = (df[
~df['education']
.isin(['Bachelors','Masters','Doctorate'])
])

lower_education_df.education.unique()
# Out:
# array(['HS-grad', '11th', '9th', 'Some-college', 'Assoc-acdm',
#        'Assoc-voc', '7th-8th', 'Prof-school', '5th-6th', '10th',
#        '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# What country has the highest percentage of people that earn >50K?
highest_earning_country = None
highest_earning_country_percentage = None
